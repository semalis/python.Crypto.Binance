# %%
# pip install shrimpy-python pandas
# pip install plotly==4.1.0

from binance.client import Client
import shrimpy
import plotly.graph_objects as go

import configparser
# Загрузка ключей из файла config
config = configparser.ConfigParser()
config.read_file(open('../secret.cfg'))
api_key = config.get('BINANCE', 'API_KEY')
api_secret = config.get('BINANCE', 'SECRET_KEY')


client = shrimpy.ShrimpyApiClient(api_key, api_secret)

# ticker = client.get_ticker('bittrex')
ticker = client.get_ticker('binance')

# %%
ticker
# Out:
# [{'name': 'Ethereum',
#   'symbol': 'ETH',
#   'priceUsd': '3879.38',
#   'priceBtc': '0.0826509721190557',
#   'percentChange24hUsd': '-3.508918562807305087',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'priceUsd': '46936.895',
#   'priceBtc': '1.0000000000000113',
#   'percentChange24hUsd': '-3.585667460587655641',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Litecoin',
#   'symbol': 'LTC',
#   'priceUsd': '147.75',
#   'priceBtc': '0.0031478435034955',
#   'percentChange24hUsd': '-3.707607212529963526',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'priceUsd': '527.95',
#   'priceBtc': '0.0112480810671436',
#   'percentChange24hUsd': '-0.78208196917117663',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'NEO',
#   'symbol': 'NEO',
#   'priceUsd': '26.29',
#   'priceBtc': '0.0005601137442091',
#   'percentChange24hUsd': '-2.856457521261880993',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Gas',
#   'symbol': 'GAS',
#   'priceUsd': '5.918742459499933',
#   'priceBtc': '0.0001261',
#   'percentChange24hUsd': '-0.467889208187586692',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tether',
#   'symbol': 'USDT',
#   'priceUsd': '0.9999277430721771',
#   'priceBtc': '0.0000213036619289',
#   'percentChange24hUsd': '0',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'MCO',
#   'symbol': 'MCO',
#   'priceUsd': '8.768964487499872',
#   'priceBtc': '0.0002115',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Waltonchain',
#   'symbol': 'WTC',
#   'priceUsd': '1.0307',
#   'priceBtc': '0.0000219592710596',
#   'percentChange24hUsd': '0.02178260105003297',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Loopring',
#   'symbol': 'LRC',
#   'priceUsd': '2.1085',
#   'priceBtc': '0.000044922017104',
#   'percentChange24hUsd': '-5.079794519993697492',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Qtum',
#   'symbol': 'QTUM',
#   'priceUsd': '9.307',
#   'priceBtc': '0.0001982875092185',
#   'percentChange24hUsd': '-4.44358560841066865',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'YOYOW',
#   'symbol': 'YOYO',
#   'priceUsd': '0.0180707045749998',
#   'priceBtc': '3.85e-7',
#   'percentChange24hUsd': '-6.026536638800706204',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'OMG Network',
#   'symbol': 'OMG',
#   'priceUsd': '6.4315',
#   'priceBtc': '0.0001370244026581',
#   'percentChange24hUsd': '2.72242679876592614',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': '0x',
#   'symbol': 'ZRX',
#   'priceUsd': '0.7708',
#   'priceBtc': '0.0000164220492216',
#   'percentChange24hUsd': '-3.201393901899109036',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'SingularDTV',
#   'symbol': 'SNGLS',
#   'priceUsd': '0.0063364808249999',
#   'priceBtc': '1.35e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Voyager Token',
#   'symbol': 'BQX',
#   'priceUsd': '3.158',
#   'priceBtc': '0.0000672818259495',
#   'percentChange24hUsd': '-7.869655663242765141',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Kyber Network',
#   'symbol': 'KNC',
#   'priceUsd': '1.2715',
#   'priceBtc': '0.0000270895635512',
#   'percentChange24hUsd': '-4.319647756135221041',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'FunFair',
#   'symbol': 'FUN',
#   'priceUsd': '0.0109',
#   'priceBtc': '2.32226695e-7',
#   'percentChange24hUsd': '1.12047921840087472',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'SONM',
#   'symbol': 'SNM',
#   'priceUsd': '0.2471227521749972',
#   'priceBtc': '0.000005265',
#   'percentChange24hUsd': '-5.996025774073043965',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'IOTA',
#   'symbol': 'IOTA',
#   'priceUsd': '1.15965',
#   'priceBtc': '0.0000247065767772',
#   'percentChange24hUsd': '2.61768781145051811',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Chainlink',
#   'symbol': 'LINK',
#   'priceUsd': '18.925',
#   'priceBtc': '0.0004032009360653',
#   'percentChange24hUsd': '-3.902678034273974259',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Verge',
#   'symbol': 'XVG',
#   'priceUsd': '0.01679',
#   'priceBtc': '3.577143311e-7',
#   'percentChange24hUsd': '-4.405275940517543506',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Moeda Loyalty Points',
#   'symbol': 'MDA',
#   'priceUsd': '0.5888233477749933',
#   'priceBtc': '0.000012545',
#   'percentChange24hUsd': '-2.888976177685521113',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Metal',
#   'symbol': 'MTL',
#   'priceUsd': '2.056',
#   'priceBtc': '0.0000438034940317',
#   'percentChange24hUsd': '-2.227837804174941519',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'EOS',
#   'symbol': 'EOS',
#   'priceUsd': '3.1925',
#   'priceBtc': '0.000068016855397',
#   'percentChange24hUsd': '-3.731925315680105439',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Status',
#   'symbol': 'SNT',
#   'priceUsd': '0.0706400269749992',
#   'priceBtc': '0.000001505',
#   'percentChange24hUsd': '-3.26428635212302989',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'priceUsd': '34.785',
#   'priceBtc': '0.0007411014299093',
#   'percentChange24hUsd': '-3.888620973011895657',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Monetha',
#   'symbol': 'MTH',
#   'priceUsd': '0.0283968214749997',
#   'priceBtc': '6.05e-7',
#   'percentChange24hUsd': '-6.670926101848929803',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'district0x',
#   'symbol': 'DNT',
#   'priceUsd': '0.13265',
#   'priceBtc': '0.0000028261349627',
#   'percentChange24hUsd': '-1.587844530987146946',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Zcash',
#   'symbol': 'ZEC',
#   'priceUsd': '149.35',
#   'priceBtc': '0.0031819318256992',
#   'percentChange24hUsd': '-5.13763585150227873',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bancor',
#   'symbol': 'BNT',
#   'priceUsd': '3.2145',
#   'priceBtc': '0.0000684855698273',
#   'percentChange24hUsd': '-3.707285107879986721',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'AirSwap',
#   'symbol': 'AST',
#   'priceUsd': '0.2961718074499966',
#   'priceBtc': '0.00000631',
#   'percentChange24hUsd': '-3.432628837509305266',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dash',
#   'symbol': 'DASH',
#   'priceUsd': '128.75',
#   'priceBtc': '0.0027430446773269',
#   'percentChange24hUsd': '-3.29755632627757335',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'OAX',
#   'symbol': 'OAX',
#   'priceUsd': '0.1905637936999978',
#   'priceBtc': '0.00000406',
#   'percentChange24hUsd': '-4.526295095118588766',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bitcoin Gold',
#   'symbol': 'BTG',
#   'priceUsd': '40.59',
#   'priceBtc': '0.0008647781239045',
#   'percentChange24hUsd': '-2.887719807202278266',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Everex',
#   'symbol': 'EVX',
#   'priceUsd': '0.615108008974993',
#   'priceBtc': '0.000013105',
#   'percentChange24hUsd': '-3.327480648125654101',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Request Network',
#   'symbol': 'REQ',
#   'priceUsd': '0.39255',
#   'priceBtc': '0.0000083633568007',
#   'percentChange24hUsd': '-4.307527969165668605',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Viberate',
#   'symbol': 'VIB',
#   'priceUsd': '0.0396616762749995',
#   'priceBtc': '8.45e-7',
#   'percentChange24hUsd': '-0.036673624781150989',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'TRON',
#   'symbol': 'TRX',
#   'priceUsd': '0.084705',
#   'priceBtc': '0.0000018046570827',
#   'percentChange24hUsd': '-2.502018800030844475',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Power Ledger',
#   'symbol': 'POWR',
#   'priceUsd': '0.4292379047749951',
#   'priceBtc': '0.000009145',
#   'percentChange24hUsd': '-6.499568284949613945',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ark',
#   'symbol': 'ARK',
#   'priceUsd': '1.1666165252249867',
#   'priceBtc': '0.000024855',
#   'percentChange24hUsd': '-1.988620234474773582',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'XRP',
#   'symbol': 'XRP',
#   'priceUsd': '0.81035',
#   'priceBtc': '0.0000172646699361',
#   'percentChange24hUsd': '-1.332129100380352688',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Enjin Coin',
#   'symbol': 'ENJ',
#   'priceUsd': '2.351',
#   'priceBtc': '0.000050088528438',
#   'percentChange24hUsd': '-5.022424224985002849',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Storj',
#   'symbol': 'STORJ',
#   'priceUsd': '1.66205',
#   'priceBtc': '0.0000354103099491',
#   'percentChange24hUsd': '-3.114356300862287333',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Komodo',
#   'symbol': 'KMD',
#   'priceUsd': '0.71375',
#   'priceBtc': '0.000015206587483',
#   'percentChange24hUsd': '-0.480783951727216576',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ripio Credit Network',
#   'symbol': 'RCN',
#   'priceUsd': '0.0347333022999996',
#   'priceBtc': '7.4e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Nuls',
#   'symbol': 'NULS',
#   'priceUsd': '0.9942',
#   'priceBtc': '0.0000211816312093',
#   'percentChange24hUsd': '-7.406235516062879309',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Raiden Network Token',
#   'symbol': 'RDN',
#   'priceUsd': '0.5451720354249938',
#   'priceBtc': '0.000011615',
#   'percentChange24hUsd': '0.345203624128443',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Monero',
#   'symbol': 'XMR',
#   'priceUsd': '185.05',
#   'priceBtc': '0.0039425275148687',
#   'percentChange24hUsd': '-1.114949446703694184',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Agrello',
#   'symbol': 'DLT',
#   'priceUsd': '0.0335598799249996',
#   'priceBtc': '7.15e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ambrosus',
#   'symbol': 'AMB',
#   'priceUsd': '0.0302742972749997',
#   'priceBtc': '6.45e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Basic Attention Token',
#   'symbol': 'BAT',
#   'priceUsd': '1.131',
#   'priceBtc': '0.0000240961827577',
#   'percentChange24hUsd': '-2.865582164010588971',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Genesis Vision',
#   'symbol': 'GVT',
#   'priceUsd': '0.8434560031499904',
#   'priceBtc': '0.00001797',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Blox',
#   'symbol': 'CDT',
#   'priceUsd': '0.1483205881999983',
#   'priceBtc': '0.00000316',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'GXChain',
#   'symbol': 'GXS',
#   'priceUsd': '2.05725',
#   'priceBtc': '0.0000438301255334',
#   'percentChange24hUsd': '18.86637555551844482',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Po.et',
#   'symbol': 'POE',
#   'priceUsd': '0.002280345375',
#   'priceBtc': '5.5e-8',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Quantstamp',
#   'symbol': 'QSP',
#   'priceUsd': '0.0410697831249995',
#   'priceBtc': '8.75e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BitShares',
#   'symbol': 'BTS',
#   'priceUsd': '0.03328',
#   'priceBtc': '7.090371018e-7',
#   'percentChange24hUsd': '-3.417281245682613059',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ZCoin',
#   'symbol': 'XZC',
#   'priceUsd': '5.605503539999918',
#   'priceBtc': '0.0001352',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Lisk',
#   'symbol': 'LSK',
#   'priceUsd': '2.352',
#   'priceBtc': '0.0000501098336394',
#   'percentChange24hUsd': '-3.003300594920429595',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tierion',
#   'symbol': 'TNT',
#   'priceUsd': '0.1088346656249984',
#   'priceBtc': '0.000002625',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Decentraland',
#   'symbol': 'MANA',
#   'priceUsd': '3.1334',
#   'priceBtc': '0.0000667577179956',
#   'percentChange24hUsd': '-4.673315804573732909',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bitcoin Diamond',
#   'symbol': 'BCD',
#   'priceUsd': '1.2461745622499858',
#   'priceBtc': '0.00002655',
#   'percentChange24hUsd': '-4.270735642430980864',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'AdEx',
#   'symbol': 'ADX',
#   'priceUsd': '0.5536',
#   'priceBtc': '0.0000117945594825',
#   'percentChange24hUsd': '-2.384195424956681674',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cardano',
#   'symbol': 'ADA',
#   'priceUsd': '1.2455',
#   'priceBtc': '0.0000265356283154',
#   'percentChange24hUsd': '-4.148518468352946169',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Populous',
#   'symbol': 'PPT',
#   'priceUsd': '0.8619960766749902',
#   'priceBtc': '0.000018365',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'CyberMiles',
#   'symbol': 'CMT',
#   'priceUsd': '0.0118163351249998',
#   'priceBtc': '2.85e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Stellar',
#   'symbol': 'XLM',
#   'priceUsd': '0.25785',
#   'priceBtc': '0.0000054935461751',
#   'percentChange24hUsd': '-3.546424988691736609',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cindicator',
#   'symbol': 'CND',
#   'priceUsd': '0.0114995392749999',
#   'priceBtc': '2.45e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tael',
#   'symbol': 'WABI',
#   'priceUsd': '0.1886863178999979',
#   'priceBtc': '0.00000402',
#   'percentChange24hUsd': '2.80785591735737226',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Time New Bank',
#   'symbol': 'TNB',
#   'priceUsd': '0.002694953625',
#   'priceBtc': '6.5e-8',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Waves',
#   'symbol': 'WAVES',
#   'priceUsd': '17.695',
#   'priceBtc': '0.0003769955383713',
#   'percentChange24hUsd': '5.49197423969986522',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Gifto',
#   'symbol': 'GTO',
#   'priceUsd': '0.060485',
#   'priceBtc': '0.0000012886451053',
#   'percentChange24hUsd': '5.27213849274741233',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ICON',
#   'symbol': 'ICX',
#   'priceUsd': '1.206',
#   'priceBtc': '0.000025694072861',
#   'percentChange24hUsd': '-0.69270085227413768',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'OST',
#   'symbol': 'OST',
#   'priceUsd': '0.0152544908749998',
#   'priceBtc': '3.25e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'aelf',
#   'symbol': 'ELF',
#   'priceUsd': '0.3687',
#   'priceBtc': '0.0000078552277478',
#   'percentChange24hUsd': '-3.06870582217263736',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Aion',
#   'symbol': 'AION',
#   'priceUsd': '0.14085',
#   'priceBtc': '0.000003000837614',
#   'percentChange24hUsd': '-3.122298402292117055',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Neblio',
#   'symbol': 'NEBL',
#   'priceUsd': '0.9765633462714702',
#   'priceBtc': '0.00002080587875',
#   'percentChange24hUsd': '-7.643420231252710334',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bread',
#   'symbol': 'BRD',
#   'priceUsd': '0.8406397894499905',
#   'priceBtc': '0.00001791',
#   'percentChange24hUsd': '1.30716901031819419',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'NavCoin',
#   'symbol': 'NAV',
#   'priceUsd': '0.3248033133999963',
#   'priceBtc': '0.00000692',
#   'percentChange24hUsd': '-5.83102594597983666',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'AppCoins',
#   'symbol': 'APPC',
#   'priceUsd': '0.0692319201249992',
#   'priceBtc': '0.000001475',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'VIBE',
#   'symbol': 'VIBE',
#   'priceUsd': '0.0176208506249997',
#   'priceBtc': '4.25e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'iExec RLC',
#   'symbol': 'RLC',
#   'priceUsd': '2.822',
#   'priceBtc': '0.0000601232782867',
#   'percentChange24hUsd': '-1.287026100691710575',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Insolar',
#   'symbol': 'INS',
#   'priceUsd': '0.2551913778749963',
#   'priceBtc': '0.000006155',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'PIVX',
#   'symbol': 'PIVX',
#   'priceUsd': '0.5451720354249938',
#   'priceBtc': '0.000011615',
#   'percentChange24hUsd': '-2.621524135193614774',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'IOST',
#   'symbol': 'IOST',
#   'priceUsd': '0.029175',
#   'priceBtc': '6.215792502e-7',
#   'percentChange24hUsd': '-3.562689638256337221',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Steem',
#   'symbol': 'STEEM',
#   'priceUsd': '0.4196158412999952',
#   'priceBtc': '0.00000894',
#   'percentChange24hUsd': '-1.266422347955827381',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Nano',
#   'symbol': 'NANO',
#   'priceUsd': '3.355',
#   'priceBtc': '0.0000714789506208',
#   'percentChange24hUsd': '-4.802314101047694732',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Viacoin',
#   'symbol': 'VIA',
#   'priceUsd': '0.3187015170499964',
#   'priceBtc': '0.00000679',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bluzelle',
#   'symbol': 'BLZ',
#   'priceUsd': '0.23025',
#   'priceBtc': '0.0000049055226171',
#   'percentChange24hUsd': '-4.215208668356596566',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Aeternity',
#   'symbol': 'AE',
#   'priceUsd': '0.1214802172499982',
#   'priceBtc': '0.00000293',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Nucleus Vision',
#   'symbol': 'NCASH',
#   'priceUsd': '0.0021141093295649',
#   'priceBtc': '4.5041525e-8',
#   'percentChange24hUsd': '-10.118828582968046042',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'POA Network',
#   'symbol': 'POA',
#   'priceUsd': '0.0190094424749998',
#   'priceBtc': '4.05e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Zilliqa',
#   'symbol': 'ZIL',
#   'priceUsd': '0.060125',
#   'priceBtc': '0.0000012809752328',
#   'percentChange24hUsd': '-3.631148712037625748',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ontology',
#   'symbol': 'ONT',
#   'priceUsd': '0.67835',
#   'priceBtc': '0.0000144523833543',
#   'percentChange24hUsd': '-2.981906467425773153',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'NEM',
#   'symbol': 'XEM',
#   'priceUsd': '0.1269',
#   'priceBtc': '0.0000027036300548',
#   'percentChange24hUsd': '-1.391476250205931911',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Wanchain',
#   'symbol': 'WAN',
#   'priceUsd': '0.63045',
#   'priceBtc': '0.0000134318642083',
#   'percentChange24hUsd': '-3.652879328973055352',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'WePower',
#   'symbol': 'WPR',
#   'priceUsd': '0.0129076461249999',
#   'priceBtc': '2.75e-7',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'QLC Chain',
#   'symbol': 'QLC',
#   'priceUsd': '0.0349679867749996',
#   'priceBtc': '7.45e-7',
#   'percentChange24hUsd': '3.35061545591674119',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Syscoin',
#   'symbol': 'SYS',
#   'priceUsd': '0.7736',
#   'priceBtc': '0.0000164817037855',
#   'percentChange24hUsd': '-1.41999210042853021',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Groestlcoin',
#   'symbol': 'GRS',
#   'priceUsd': '0.7737547140749912',
#   'priceBtc': '0.000016485',
#   'percentChange24hUsd': '12.68275589593840348',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Loom Network',
#   'symbol': 'LOOM',
#   'priceUsd': '0.0804967749249991',
#   'priceBtc': '0.000001715',
#   'percentChange24hUsd': '-2.448035218234790356',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Augur',
#   'symbol': 'REP',
#   'priceUsd': '16.55',
#   'priceBtc': '0.0003526010827943',
#   'percentChange24hUsd': '-1.744161837052521119',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'TrueUSD',
#   'symbol': 'TUSD',
#   'priceUsd': '0.99975',
#   'priceBtc': '0.000021299875077',
#   'percentChange24hUsd': '0.00722621461566668',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Horizen',
#   'symbol': 'ZEN',
#   'priceUsd': '66.955',
#   'priceBtc': '0.0014264897582169',
#   'percentChange24hUsd': '-0.275763925651029697',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Skycoin',
#   'symbol': 'SKY',
#   'priceUsd': '0.3886374905999956',
#   'priceBtc': '0.00000828',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Civic',
#   'symbol': 'CVC',
#   'priceUsd': '0.3319',
#   'priceBtc': '0.0000070711963371',
#   'percentChange24hUsd': '-3.327804338239653868',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Theta Token',
#   'symbol': 'THETA',
#   'priceUsd': '4.1555',
#   'priceBtc': '0.0000885337643234',
#   'percentChange24hUsd': '-4.868941619459517968',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'IoTeX',
#   'symbol': 'IOTX',
#   'priceUsd': '0.1167',
#   'priceBtc': '0.0000024863170007',
#   'percentChange24hUsd': '4.64308526020135155',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'QuarkChain',
#   'symbol': 'QKC',
#   'priceUsd': '0.0199481803749998',
#   'priceBtc': '4.25e-7',
#   'percentChange24hUsd': '-1.852492754238674407',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'SingularityNET',
#   'symbol': 'AGI',
#   'priceUsd': '0.2806897852499959',
#   'priceBtc': '0.00000677',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Nexus',
#   'symbol': 'NXS',
#   'priceUsd': '0.521703587924994',
#   'priceBtc': '0.000011115',
#   'percentChange24hUsd': '-1.548433056907000349',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Streamr DATAcoin',
#   'symbol': 'DATA',
#   'priceUsd': '0.11334',
#   'priceBtc': '0.0000024147315241',
#   'percentChange24hUsd': '-6.49382099175987825',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Siacoin',
#   'symbol': 'SC',
#   'priceUsd': '0.01523',
#   'priceBtc': '3.24478217e-7',
#   'percentChange24hUsd': '-4.835360496373994779',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Pundi X',
#   'symbol': 'NPXS',
#   'priceUsd': '0.0070607',
#   'priceBtc': '1.702981067e-7',
#   'percentChange24hUsd': '-9.777944266183277433',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Selfkey',
#   'symbol': 'KEY',
#   'priceUsd': '0.0121685',
#   'priceBtc': '2.59252343e-7',
#   'percentChange24hUsd': '-4.512697053271178279',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Nebulas',
#   'symbol': 'NAS',
#   'priceUsd': '0.3262114202499963',
#   'priceBtc': '0.00000695',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mainframe',
#   'symbol': 'MFT',
#   'priceUsd': '0.008572',
#   'priceBtc': '1.826281862e-7',
#   'percentChange24hUsd': '-3.488663855207002832',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dent',
#   'symbol': 'DENT',
#   'priceUsd': '0.003339',
#   'priceBtc': '7.11380674e-8',
#   'percentChange24hUsd': '-5.310044485157442065',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ardor',
#   'symbol': 'ARDR',
#   'priceUsd': '0.2292',
#   'priceBtc': '0.0000048831521557',
#   'percentChange24hUsd': '-1.581553248011266528',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Holo',
#   'symbol': 'HOT',
#   'priceUsd': '0.0076905',
#   'priceBtc': '1.638476512e-7',
#   'percentChange24hUsd': '-5.798815200253898681',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'VeChain',
#   'symbol': 'VET',
#   'priceUsd': '0.082285',
#   'priceBtc': '0.0000017530984953',
#   'percentChange24hUsd': '-1.092612873035240938',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dock',
#   'symbol': 'DOCK',
#   'priceUsd': '0.06308',
#   'priceBtc': '0.0000013439321029',
#   'percentChange24hUsd': '-2.019789866252939385',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Polymath',
#   'symbol': 'POLY',
#   'priceUsd': '0.4918',
#   'priceBtc': '0.0000104778980374',
#   'percentChange24hUsd': '-3.400660212959408683',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'GoChain',
#   'symbol': 'GO',
#   'priceUsd': '0.0354373557249996',
#   'priceBtc': '7.55e-7',
#   'percentChange24hUsd': '1.80814135280595522',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'HyperCash',
#   'symbol': 'HC',
#   'priceUsd': '0.8354356237499878',
#   'priceBtc': '0.00002015',
#   'percentChange24hUsd': '-3.5856674605877374',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Ravencoin',
#   'symbol': 'RVN',
#   'priceUsd': '0.083695',
#   'priceBtc': '0.0000017831388293',
#   'percentChange24hUsd': '-3.736575063862255373',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Paxos Standard Token',
#   'symbol': 'PAX',
#   'priceUsd': '0.9103330949209011',
#   'priceBtc': '0.0000193948299077',
#   'percentChange24hUsd': '-3.585667460552062072',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Decred',
#   'symbol': 'DCR',
#   'priceUsd': '65.15',
#   'priceBtc': '0.0013880338697309',
#   'percentChange24hUsd': '-2.096607244257899868',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'USD//Coin',
#   'symbol': 'USDC',
#   'priceUsd': '0.99975',
#   'priceBtc': '0.000021299875077',
#   'percentChange24hUsd': '0.01723043898091191',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mithril',
#   'symbol': 'MITH',
#   'priceUsd': '0.064195',
#   'priceBtc': '0.0000013676874024',
#   'percentChange24hUsd': '8.10749998819650892',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ren',
#   'symbol': 'REN',
#   'priceUsd': '0.5061',
#   'priceBtc': '0.000010782562417',
#   'percentChange24hUsd': '-5.843815110944378332',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BitTorrent',
#   'symbol': 'BTT',
#   'priceUsd': '0.0027055',
#   'priceBtc': '5.76412223e-8',
#   'percentChange24hUsd': '-3.004283652095536463',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Celer Network',
#   'symbol': 'CELR',
#   'priceUsd': '0.07951',
#   'priceBtc': '0.0000016939765615',
#   'percentChange24hUsd': '14.60903079374897141',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'priceUsd': '21.435',
#   'priceBtc': '0.0004566769915223',
#   'percentChange24hUsd': '-5.545058651047272138',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Polygon',
#   'symbol': 'MATIC',
#   'priceUsd': '2.0405',
#   'priceBtc': '0.0000434732634104',
#   'percentChange24hUsd': '-2.895672095599447872',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Fetch',
#   'symbol': 'FET',
#   'priceUsd': '0.48695',
#   'priceBtc': '0.0000103745678107',
#   'percentChange24hUsd': '-2.748839130668630461',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ontology Gas',
#   'symbol': 'ONG',
#   'priceUsd': '0.7574',
#   'priceBtc': '0.0000161365595232',
#   'percentChange24hUsd': '-1.820514406841027663',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Theta Fuel',
#   'symbol': 'TFUEL',
#   'priceUsd': '0.1977',
#   'priceBtc': '0.0000042120383123',
#   'percentChange24hUsd': '-5.036365885857590026',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Phoenix',
#   'symbol': 'PHB',
#   'priceUsd': '0.4667874207749947',
#   'priceBtc': '0.000009945',
#   'percentChange24hUsd': '-6.225864341862596755',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Harmony',
#   'symbol': 'ONE',
#   'priceUsd': '0.195725',
#   'priceBtc': '0.0000041699605396',
#   'percentChange24hUsd': '-2.298962534283914194',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Fantom',
#   'symbol': 'FTM',
#   'priceUsd': '1.41935',
#   'priceBtc': '0.0000302395375749',
#   'percentChange24hUsd': '-6.838672577184780671',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Algorand',
#   'symbol': 'ALGO',
#   'priceUsd': '1.36805',
#   'priceBtc': '0.0000291465807442',
#   'percentChange24hUsd': '-3.68540244745904046',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'priceUsd': '0.17245',
#   'priceBtc': '0.0000036740819775',
#   'percentChange24hUsd': '-3.625335787640238826',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dusk Network',
#   'symbol': 'DUSK',
#   'priceUsd': '0.52075',
#   'priceBtc': '0.0000110946836172',
#   'percentChange24hUsd': '-11.813118192723616319',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'WINk',
#   'symbol': 'WIN',
#   'priceUsd': '0.00048685',
#   'priceBtc': '1.03724373e-8',
#   'percentChange24hUsd': '1.24457871354178373',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Contentos',
#   'symbol': 'COS',
#   'priceUsd': '0.02709',
#   'priceBtc': '5.771579053e-7',
#   'percentChange24hUsd': '5.72471252158730262',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'TomoChain',
#   'symbol': 'TOMO',
#   'priceUsd': '1.926',
#   'priceBtc': '0.0000410338178527',
#   'percentChange24hUsd': '-3.257700808893879183',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ankr',
#   'symbol': 'ANKR',
#   'priceUsd': '0.10048',
#   'priceBtc': '0.0000021407466344',
#   'percentChange24hUsd': '-4.651996486593937655',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cocos-BCX',
#   'symbol': 'COCOS',
#   'priceUsd': '2.62115',
#   'priceBtc': '0.0000558441285901',
#   'percentChange24hUsd': '29.11093975925110614',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Perlin',
#   'symbol': 'PERL',
#   'priceUsd': '0.07344',
#   'priceBtc': '0.0000015646539891',
#   'percentChange24hUsd': '-3.60243216960946176',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Chiliz',
#   'symbol': 'CHZ',
#   'priceUsd': '0.27595',
#   'priceBtc': '0.0000058791703201',
#   'percentChange24hUsd': '-3.422592916469076071',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tezos',
#   'symbol': 'XTZ',
#   'priceUsd': '4.243',
#   'priceBtc': '0.0000903979694439',
#   'percentChange24hUsd': '-4.192670844575154948',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Band Protocol',
#   'symbol': 'BAND',
#   'priceUsd': '4.975',
#   'priceBtc': '0.000105993376852',
#   'percentChange24hUsd': '-3.240771991735222071',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Beam',
#   'symbol': 'BEAM',
#   'priceUsd': '0.5931',
#   'priceBtc': '0.0000126361149369',
#   'percentChange24hUsd': '-3.073313394691839485',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Hedera Hashgraph',
#   'symbol': 'HBAR',
#   'priceUsd': '0.257',
#   'priceBtc': '0.000005475436754',
#   'percentChange24hUsd': '-2.496748341456646661',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Binance USD',
#   'symbol': 'BUSD',
#   'priceUsd': '0.99965',
#   'priceBtc': '0.0000212977445568',
#   'percentChange24hUsd': '0.0072262148809888',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'NKN',
#   'symbol': 'NKN',
#   'priceUsd': '0.34965',
#   'priceBtc': '0.0000074493636616',
#   'percentChange24hUsd': '-1.235625911271818932',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Stacks',
#   'symbol': 'STX',
#   'priceUsd': '2.07',
#   'priceBtc': '0.000044101766851',
#   'percentChange24hUsd': '-5.644959770064420329',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Kava',
#   'symbol': 'KAVA',
#   'priceUsd': '3.7425',
#   'priceBtc': '0.0000797347161545',
#   'percentChange24hUsd': '7.13526380679985288',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ARPA Chain',
#   'symbol': 'ARPA',
#   'priceUsd': '0.10579',
#   'priceBtc': '0.0000022538772537',
#   'percentChange24hUsd': '11.85456955470762337',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cortex',
#   'symbol': 'CTXC',
#   'priceUsd': '0.50955',
#   'priceBtc': '0.0000108560653618',
#   'percentChange24hUsd': '45.24350040618812875',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'priceUsd': '432.15',
#   'priceBtc': '0.0092070427751986',
#   'percentChange24hUsd': '-2.891533965335814429',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Vite',
#   'symbol': 'VITE',
#   'priceUsd': '0.07721',
#   'priceBtc': '0.0000016449745983',
#   'percentChange24hUsd': '-0.78943934032567958',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Troy',
#   'symbol': 'TROY',
#   'priceUsd': '0.010489',
#   'priceBtc': '2.234702572e-7',
#   'percentChange24hUsd': '-2.714973726377741135',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'FTX Token',
#   'symbol': 'FTT',
#   'priceUsd': '37.605',
#   'priceBtc': '0.0008011820977932',
#   'percentChange24hUsd': '-3.085382249510163133',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Turkish Lira',
#   'symbol': 'TRY',
#   'priceUsd': '0.0621137302999801',
#   'priceBtc': '0.0000013233455323',
#   'percentChange24hUsd': '-5.446753401048084548',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Euro',
#   'symbol': 'EUR',
#   'priceUsd': '1.1324780472378448',
#   'priceBtc': '0.0000241276728518',
#   'percentChange24hUsd': '0.26601518436721623',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'TokenClub',
#   'symbol': 'TCT',
#   'priceUsd': '0.02967',
#   'priceBtc': '6.321253249e-7',
#   'percentChange24hUsd': '-3.285058610725783647',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Origin Protocol',
#   'symbol': 'OGN',
#   'priceUsd': '0.62335',
#   'priceBtc': '0.0000132805972785',
#   'percentChange24hUsd': '-1.314699286317298551',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'DREP',
#   'symbol': 'DREP',
#   'priceUsd': '0.83895',
#   'priceBtc': '0.0000178739986955',
#   'percentChange24hUsd': '11.43719276546876292',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'WazirX',
#   'symbol': 'WRX',
#   'priceUsd': '1.0995',
#   'priceBtc': '0.0000234250689143',
#   'percentChange24hUsd': '-1.471375247914956185',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'LTO Network',
#   'symbol': 'LTO',
#   'priceUsd': '0.36175',
#   'priceBtc': '0.0000077071565982',
#   'percentChange24hUsd': '9.74553036033766356',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'MovieBloc',
#   'symbol': 'MBL',
#   'priceUsd': '0.0082935',
#   'priceBtc': '1.766946876e-7',
#   'percentChange24hUsd': '-2.719923668969079704',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'COTI',
#   'symbol': 'COTI',
#   'priceUsd': '0.30895',
#   'priceBtc': '0.0000065822419655',
#   'percentChange24hUsd': '-4.785107737568604097',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Standard Tokenization Protocol',
#   'symbol': 'STPT',
#   'priceUsd': '0.106705',
#   'priceBtc': '0.000002273371513',
#   'percentChange24hUsd': '4.16585556250916801',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Solana',
#   'symbol': 'SOL',
#   'priceUsd': '177.355',
#   'priceBtc': '0.0037785839902704',
#   'percentChange24hUsd': '-1.234615333537923754',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Cartesi',
#   'symbol': 'CTSI',
#   'priceUsd': '0.651',
#   'priceBtc': '0.0000138696860966',
#   'percentChange24hUsd': '-5.686362065725265557',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Hive',
#   'symbol': 'HIVE',
#   'priceUsd': '1.43525',
#   'priceBtc': '0.0000305782902768',
#   'percentChange24hUsd': '-4.312941952037471586',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Chromia',
#   'symbol': 'CHR',
#   'priceUsd': '0.5783',
#   'priceBtc': '0.0000123207979565',
#   'percentChange24hUsd': '3.63619553796713166',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BTCUP',
#   'symbol': 'BTCUP',
#   'priceUsd': '67.97',
#   'priceBtc': '0.0014481145376148',
#   'percentChange24hUsd': '-9.697292365669338933',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BTCDOWN',
#   'symbol': 'BTCDOWN',
#   'priceUsd': '0.012933',
#   'priceBtc': '2.755401694e-7',
#   'percentChange24hUsd': '9.70258327686460826',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Measurable Data Token',
#   'symbol': 'MDT',
#   'priceUsd': '0.094665',
#   'priceBtc': '0.0000020168568884',
#   'percentChange24hUsd': '7.54497409329938681',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'StormX',
#   'symbol': 'STMX',
#   'priceUsd': '0.02189',
#   'priceBtc': '4.663708581e-7',
#   'percentChange24hUsd': '-0.83088644543665987',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Rupiah Token',
#   'symbol': 'IDRT',
#   'priceUsd': '0.0000694010741248',
#   'priceBtc': '1.4786039e-9',
#   'percentChange24hUsd': '-0.232216928936880917',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Everipedia',
#   'symbol': 'IQ',
#   'priceUsd': '0.0117357219538568',
#   'priceBtc': '2.500319195e-7',
#   'percentChange24hUsd': '-2.633327608921319813',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'DigiByte',
#   'symbol': 'DGB',
#   'priceUsd': '0.03474',
#   'priceBtc': '7.401426958e-7',
#   'percentChange24hUsd': '-1.774072978332131766',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'pNetwork Token',
#   'symbol': 'PNT',
#   'priceUsd': '0.8566',
#   'priceBtc': '0.0000182500354998',
#   'percentChange24hUsd': '1.11087633614108349',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Swipe',
#   'symbol': 'SXP',
#   'priceUsd': '1.4495',
#   'priceBtc': '0.0000308818893964',
#   'percentChange24hUsd': '-4.158364034056772794',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Synthetix Network Token',
#   'symbol': 'SNX',
#   'priceUsd': '4.9775',
#   'priceBtc': '0.0001060466398555',
#   'percentChange24hUsd': '-3.154480839691616933',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Compound',
#   'symbol': 'COMP',
#   'priceUsd': '187.3',
#   'priceBtc': '0.0039904642179676',
#   'percentChange24hUsd': '-3.297091016867164034',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ADAUP',
#   'symbol': 'ADAUP',
#   'priceUsd': '27.3995',
#   'priceBtc': '0.0005837518651372',
#   'percentChange24hUsd': '-9.431565206654006697',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ADADOWN',
#   'symbol': 'ADADOWN',
#   'priceUsd': '0.0076255',
#   'priceBtc': '1.624628131e-7',
#   'percentChange24hUsd': '7.81156476232821234',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'LINKUP',
#   'symbol': 'LINKUP',
#   'priceUsd': '0.48295',
#   'priceBtc': '0.0000102893470052',
#   'percentChange24hUsd': '-8.499592875588895321',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'LINKDOWN',
#   'symbol': 'LINKDOWN',
#   'priceUsd': '0.01687',
#   'priceBtc': '3.594187472e-7',
#   'percentChange24hUsd': '7.26527679790452482',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ETHUP',
#   'symbol': 'ETHUP',
#   'priceUsd': '87.825',
#   'priceBtc': '0.001871129310961',
#   'percentChange24hUsd': '-7.150117423592586061',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'ETHDOWN',
#   'symbol': 'ETHDOWN',
#   'priceUsd': '0.5753',
#   'priceBtc': '0.0000122568823524',
#   'percentChange24hUsd': '6.67313848382389784',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Maker',
#   'symbol': 'MKR',
#   'priceUsd': '2305.5',
#   'priceBtc': '0.0491191417753566',
#   'percentChange24hUsd': '-3.285796963829589354',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Dai',
#   'symbol': 'DAI',
#   'priceUsd': '0.9995825125307901',
#   'priceBtc': '0.0000212963067227',
#   'percentChange24hUsd': '-0.01840354992148898',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'IRISnet',
#   'symbol': 'IRIS',
#   'priceUsd': '0.080495',
#   'priceBtc': '0.0000017149621849',
#   'percentChange24hUsd': '-3.701397519635726298',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'VeThor Token',
#   'symbol': 'VTHO',
#   'priceUsd': '0.005658',
#   'priceBtc': '1.205448294e-7',
#   'percentChange24hUsd': '-0.938220254682133313',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'FIO Protocol',
#   'symbol': 'FIO',
#   'priceUsd': '0.17225',
#   'priceBtc': '0.0000036698209372',
#   'percentChange24hUsd': '17.74603359874752851',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'THORChain',
#   'symbol': 'RUNE',
#   'priceUsd': '6.353',
#   'priceBtc': '0.00013535194435',
#   'percentChange24hUsd': '-5.369986871825312406',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Travala.com',
#   'symbol': 'AVA',
#   'priceUsd': '1.7695',
#   'priceBtc': '0.0000376995538371',
#   'percentChange24hUsd': '0.91975294398564237',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Balancer',
#   'symbol': 'BAL',
#   'priceUsd': '14.63',
#   'priceBtc': '0.0003116950961498',
#   'percentChange24hUsd': '-2.880469995192505672',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BNBUP',
#   'symbol': 'BNBUP',
#   'priceUsd': '564.01',
#   'priceBtc': '0.0120163466288089',
#   'percentChange24hUsd': '-1.970705682386625506',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BNBDOWN',
#   'symbol': 'BNBDOWN',
#   'priceUsd': '0.085645',
#   'priceBtc': '0.000001824683972',
#   'percentChange24hUsd': '1.85656902621299903',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'XTZUP',
#   'symbol': 'XTZUP',
#   'priceUsd': '0.01332',
#   'priceBtc': '2.837852823e-7',
#   'percentChange24hUsd': '-11.927520462090925189',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'XTZDOWN',
#   'symbol': 'XTZDOWN',
#   'priceUsd': '2.2005',
#   'priceBtc': '0.0000468820956307',
#   'percentChange24hUsd': '9.70383912541278308',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'yearn.finance',
#   'symbol': 'YFI',
#   'priceUsd': '26031.435',
#   'priceBtc': '0.5546049648149988',
#   'percentChange24hUsd': '23.85201634661969927',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Just',
#   'symbol': 'JST',
#   'priceUsd': '0.0575',
#   'priceBtc': '0.0000012250490792',
#   'percentChange24hUsd': '-2.930190626395497879',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Aragon',
#   'symbol': 'ANT',
#   'priceUsd': '6.2355',
#   'priceBtc': '0.0001328485831881',
#   'percentChange24hUsd': '-12.299408049740833854',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ocean Protocol',
#   'symbol': 'OCEAN',
#   'priceUsd': '0.78335',
#   'priceBtc': '0.0000166894294989',
#   'percentChange24hUsd': '-5.419943673552764529',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Numeraire',
#   'symbol': 'NMR',
#   'priceUsd': '31.685',
#   'priceBtc': '0.0006750553056396',
#   'percentChange24hUsd': '-1.393217282842028997',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Serum',
#   'symbol': 'SRM',
#   'priceUsd': '3.387',
#   'priceBtc': '0.0000721607170649',
#   'percentChange24hUsd': '-5.831394164652043591',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Curve DAO Token',
#   'symbol': 'CRV',
#   'priceUsd': '3.7385',
#   'priceBtc': '0.000079649495349',
#   'percentChange24hUsd': '-1.624255965277215852',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'British Pound',
#   'symbol': 'GBP',
#   'priceUsd': '1.3305',
#   'priceBtc': '0.0000283465704325',
#   'percentChange24hUsd': '0.22650933891443256',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Australian Dollar',
#   'symbol': 'AUD',
#   'priceUsd': '0.71605',
#   'priceBtc': '0.0000152555894462',
#   'percentChange24hUsd': '-0.11831462274152568',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'South African Rand',
#   'symbol': 'ZAR',
#   'priceUsd': '0.0490290977169375',
#   'priceBtc': '0.0000011825403309',
#   'percentChange24hUsd': '-3.585667456554142563',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Russian Ruble',
#   'symbol': 'RUB',
#   'priceUsd': '0.0135308843052178',
#   'priceBtc': '2.882782149e-7',
#   'percentChange24hUsd': '-0.479920811375198451',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Nigerian Naira',
#   'symbol': 'NGN',
#   'priceUsd': '0.0017260068858795',
#   'priceBtc': '3.67729243e-8',
#   'percentChange24hUsd': '-0.155361634102086378',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ukrainian Hryvnia',
#   'symbol': 'UAH',
#   'priceUsd': '0.0360685313804679',
#   'priceBtc': '7.684473244e-7',
#   'percentChange24hUsd': '-0.245271759561140584',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Polkadot',
#   'symbol': 'DOT',
#   'priceUsd': '25.475',
#   'priceBtc': '0.0005427500050866',
#   'percentChange24hUsd': '-5.167165910208847543',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tellor',
#   'symbol': 'TRB',
#   'priceUsd': '31.715',
#   'priceBtc': '0.000675694461681',
#   'percentChange24hUsd': '-2.588170165766182883',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Reserve Rights',
#   'symbol': 'RSR',
#   'priceUsd': '0.03317',
#   'priceBtc': '7.066935297e-7',
#   'percentChange24hUsd': '1.72461494697019372',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'PAX Gold',
#   'symbol': 'PAXG',
#   'priceUsd': '1812.5',
#   'priceBtc': '0.0386156774963495',
#   'percentChange24hUsd': '1.5764065644897865',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Terra',
#   'symbol': 'LUNA',
#   'priceUsd': '64.185',
#   'priceBtc': '0.0013674743504018',
#   'percentChange24hUsd': '0.88744698777510397',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'bZx Protocol',
#   'symbol': 'BZRX',
#   'priceUsd': '0.24495',
#   'priceBtc': '0.0000052187090774',
#   'percentChange24hUsd': '-13.101205883524102131',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'The Sandbox',
#   'symbol': 'SAND',
#   'priceUsd': '4.92235',
#   'priceBtc': '0.0001048716579995',
#   'percentChange24hUsd': '-4.871575721103041391',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Wrapped Bitcoin',
#   'symbol': 'WBTC',
#   'priceUsd': '46943.93553424947',
#   'priceBtc': '1.00015',
#   'percentChange24hUsd': '-3.590487213264172718',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'yearn.finance II',
#   'symbol': 'YFII',
#   'priceUsd': '2815.5',
#   'priceBtc': '0.0599847944777777',
#   'percentChange24hUsd': '0.61473839834907505',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Kusama',
#   'symbol': 'KSM',
#   'priceUsd': '275.95',
#   'priceBtc': '0.0058791703200649',
#   'percentChange24hUsd': '-3.893456124063546014',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'DIA',
#   'symbol': 'DIA',
#   'priceUsd': '1.243',
#   'priceBtc': '0.000026482365312',
#   'percentChange24hUsd': '-1.964525090597044572',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'eGLD',
#   'symbol': 'EGLD',
#   'priceUsd': '266.395',
#   'priceBtc': '0.0056755991209048',
#   'percentChange24hUsd': '-15.670343670888790112',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'IDEX',
#   'symbol': 'IDEX',
#   'priceUsd': '0.271475',
#   'priceBtc': '0.0000057838295439',
#   'percentChange24hUsd': '-4.119714166627391821',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Sushiswap',
#   'symbol': 'SUSHI',
#   'priceUsd': '5.684',
#   'priceBtc': '0.0001210987646286',
#   'percentChange24hUsd': '-3.539610757654525856',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'UMA',
#   'symbol': 'UMA',
#   'priceUsd': '9.012',
#   'priceBtc': '0.0001920024748122',
#   'percentChange24hUsd': '-3.432430874543045006',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Wrapped NXM',
#   'symbol': 'WNXM',
#   'priceUsd': '67.91',
#   'priceBtc': '0.0014468362255322',
#   'percentChange24hUsd': '-1.842885789167954125',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Binance KRW',
#   'symbol': 'BKRW',
#   'priceUsd': '0.000987382080404',
#   'priceBtc': '2.38148199e-8',
#   'percentChange24hUsd': '-3.585667448516573493',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Swerve',
#   'symbol': 'SWRV',
#   'priceUsd': '0.796213642837331',
#   'priceBtc': '0.000016963492',
#   'percentChange24hUsd': '-0.776284091683954078',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Uniswap',
#   'symbol': 'UNI',
#   'priceUsd': '14.265',
#   'priceBtc': '0.0003039186976471',
#   'percentChange24hUsd': '-4.47920442222159664',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Orchid',
#   'symbol': 'OXT',
#   'priceUsd': '0.36185',
#   'priceBtc': '0.0000077092871184',
#   'percentChange24hUsd': '-3.215793511987913524',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'SUN',
#   'symbol': 'SUN',
#   'priceUsd': '0.023075',
# ...
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Phala Network',
#   'symbol': 'PHA',
#   'priceUsd': '0.36175',
#   'priceBtc': '0.0000077071565982',
#   'percentChange24hUsd': '1.26693935088228585',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Beefy.Finance',
#   'symbol': 'BIFI',
#   'priceUsd': '1359.804307822091',
#   'priceBtc': '0.0289709046118646',
#   'percentChange24hUsd': '-0.23606963088848485',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Linear',
#   'symbol': 'LINA',
#   'priceUsd': '0.03724',
#   'priceBtc': '7.934056993e-7',
#   'percentChange24hUsd': '-2.684371455751667211',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Stafi',
#   'symbol': 'FIS',
#   'priceUsd': '1.11105',
#   'priceBtc': '0.0000236711439902',
#   'percentChange24hUsd': '-3.148373339733132115',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'MyNeighborAlice',
#   'symbol': 'ALICE',
#   'priceUsd': '12.445',
#   'priceBtc': '0.0002651432311405',
#   'percentChange24hUsd': '-2.116403441354567667',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ramp',
#   'symbol': 'RAMP',
#   'priceUsd': '0.2029',
#   'priceBtc': '0.0000043228253595',
#   'percentChange24hUsd': '-0.823723366704077254',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Superfarm',
#   'symbol': 'SUPER',
#   'priceUsd': '1.2233',
#   'priceBtc': '0.0000260626528448',
#   'percentChange24hUsd': '-8.164366003474005612',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Conflux Network',
#   'symbol': 'CFX',
#   'priceUsd': '0.20265',
#   'priceBtc': '0.0000043174990591',
#   'percentChange24hUsd': '-1.475622787452643324',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Perpetual Protocol',
#   'symbol': 'PERP',
#   'priceUsd': '8.685',
#   'priceBtc': '0.0001850356739618',
#   'percentChange24hUsd': '-1.579290688341099891',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ellipsis',
#   'symbol': 'EPS',
#   'priceUsd': '0.2615',
#   'priceBtc': '0.0000055713101602',
#   'percentChange24hUsd': '-1.070967826301755376',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Pundi X',
#   'symbol': 'PUNDIX',
#   'priceUsd': '1',
#   'priceBtc': '0.0000213052013773',
#   'percentChange24hUsd': '-3.931579044424339322',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Toko Token',
#   'symbol': 'TKO',
#   'priceUsd': '1.2025',
#   'priceBtc': '0.0000256195046562',
#   'percentChange24hUsd': '-4.74559245671081156',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mirror Protocol',
#   'symbol': 'MIR',
#   'priceUsd': '2.235',
#   'priceBtc': '0.0000476171250783',
#   'percentChange24hUsd': '-4.31671635697153206',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Juventus Fan Token',
#   'symbol': 'JUV',
#   'priceUsd': '8.37',
#   'priceBtc': '0.000178324535528',
#   'percentChange24hUsd': '-2.780431658785754785',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ampleforth Governance Token',
#   'symbol': 'FORTH',
#   'priceUsd': '9.46',
#   'priceBtc': '0.0002015472050292',
#   'percentChange24hUsd': '-7.429710372597864248',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Auto',
#   'symbol': 'AUTO',
#   'priceUsd': '617.25',
#   'priceBtc': '0.0131506355501361',
#   'percentChange24hUsd': '-1.01112831769124102',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'UniLend',
#   'symbol': 'UFT',
#   'priceUsd': '0.6192982650734467',
#   'priceBtc': '0.00001319427425',
#   'percentChange24hUsd': '-6.480234011390700832',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Shiba Inu',
#   'symbol': 'SHIB',
#   'priceUsd': '0.000032505',
#   'priceBtc': '6.925256e-10',
#   'percentChange24hUsd': '-3.78171338394576689',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Polkastarter',
#   'symbol': 'POLS',
#   'priceUsd': '3.004',
#   'priceBtc': '0.0000640008249374',
#   'percentChange24hUsd': '-6.147545282986568889',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'priceUsd': '24.23',
#   'priceBtc': '0.0005162250293719',
#   'percentChange24hUsd': '-6.783031691302237683',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'QuickSwap',
#   'symbol': 'QUICK',
#   'priceUsd': '240.55',
#   'priceBtc': '0.0051249661913086',
#   'percentChange24hUsd': '-2.801057511227467923',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'FC Barcelona Fan Token',
#   'symbol': 'BAR',
#   'priceUsd': '8.33',
#   'priceBtc': '0.0001774723274729',
#   'percentChange24hUsd': '-4.410763698306703654',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mdex',
#   'symbol': 'MDX',
#   'priceUsd': '0.4005',
#   'priceBtc': '0.0000085327331516',
#   'percentChange24hUsd': '6.1003817199319463',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Agix',
#   'symbol': 'AGIX',
#   'priceUsd': '0.1842273128749979',
#   'priceBtc': '0.000003925',
#   'percentChange24hUsd': '-4.558321508904632806',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'NuCypher',
#   'symbol': 'NU',
#   'priceUsd': '0.71645',
#   'priceBtc': '0.0000152641115268',
#   'percentChange24hUsd': '-1.633474435023030556',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Livepeer',
#   'symbol': 'LPT',
#   'priceUsd': '37.185',
#   'priceBtc': '0.0007922339132148',
#   'percentChange24hUsd': '-0.806382854162709356',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Arweave',
#   'symbol': 'AR',
#   'priceUsd': '48.48',
#   'priceBtc': '0.0010328761627713',
#   'percentChange24hUsd': '12.2173435225948088',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Alien Worlds',
#   'symbol': 'TLM',
#   'priceUsd': '0.21135',
#   'priceBtc': '0.0000045028543111',
#   'percentChange24hUsd': '-4.510832344412466768',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Keep Network',
#   'symbol': 'KEEP',
#   'priceUsd': '0.604',
#   'priceBtc': '0.0000128683416319',
#   'percentChange24hUsd': '-5.948828908017735484',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mask Network',
#   'symbol': 'MASK',
#   'priceUsd': '10.8875',
#   'priceBtc': '0.0002319603799953',
#   'percentChange24hUsd': '-0.64071949503998888',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Gitcoin',
#   'symbol': 'GTC',
#   'priceUsd': '9.6535',
#   'priceBtc': '0.0002056697614957',
#   'percentChange24hUsd': '-2.497625787540690633',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tornado Cash',
#   'symbol': 'TORN',
#   'priceUsd': '37.455',
#   'priceBtc': '0.0007979863175866',
#   'percentChange24hUsd': '1.20969083694667462',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Klaytn',
#   'symbol': 'KLAY',
#   'priceUsd': '1.2865',
#   'priceBtc': '0.0000274091415719',
#   'percentChange24hUsd': '1.4263275720249702',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Enzyme',
#   'symbol': 'MLN',
#   'priceUsd': '82.9',
#   'priceBtc': '0.0017662011941779',
#   'percentChange24hUsd': '-3.429248069806085174',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BarnBridge',
#   'symbol': 'BOND',
#   'priceUsd': '15.68',
#   'priceBtc': '0.000334065557596',
#   'percentChange24hUsd': '2.52457058175673222',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'EasyFi',
#   'symbol': 'EZ',
#   'priceUsd': '3.1938210202749637',
#   'priceBtc': '0.000068045',
#   'percentChange24hUsd': '-3.66353513003953875',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Clover Finance',
#   'symbol': 'CLV',
#   'priceUsd': '0.8255',
#   'priceBtc': '0.000017587443737',
#   'percentChange24hUsd': '0.00722621473528186',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Quant',
#   'symbol': 'QNT',
#   'priceUsd': '179.75',
#   'priceBtc': '0.003829609947569',
#   'percentChange24hUsd': '-2.009817868025153044',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Flow (Dapper Labs)',
#   'symbol': 'FLOW',
#   'priceUsd': '8.455',
#   'priceBtc': '0.000180135477645',
#   'percentChange24hUsd': '-4.077016716254962221',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Mina',
#   'symbol': 'MINA',
#   'priceUsd': '3.25',
#   'priceBtc': '0.0000692419044762',
#   'percentChange24hUsd': '-7.833975557097659687',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Harvest Finance',
#   'symbol': 'FARM',
#   'priceUsd': '87.45',
#   'priceBtc': '0.0018631398604446',
#   'percentChange24hUsd': '-0.730625056926489947',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Binance VND',
#   'symbol': 'BVND',
#   'priceUsd': '0.0000421505352502',
#   'priceBtc': '8.980256e-10',
#   'percentChange24hUsd': '0.00722235223012251',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'GYEN',
#   'symbol': 'GYEN',
#   'priceUsd': '0.0092338780394141',
#   'priceBtc': '2.227133213e-7',
#   'percentChange24hUsd': '-3.585667462402987405',
#   'lastUpdated': '2021-07-31T13:28:00.000Z'},
#  {'name': 'Automata Network',
#   'symbol': 'ATA',
#   'priceUsd': '0.62465',
#   'priceBtc': '0.0000133082940403',
#   'percentChange24hUsd': '-3.907839016654119915',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Ethernity Chain',
#   'symbol': 'ERN',
#   'priceUsd': '9.342',
#   'priceBtc': '0.0001990331912667',
#   'percentChange24hUsd': '-5.155321323924999951',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Coin98',
#   'symbol': 'C98',
#   'priceUsd': '2.0235',
#   'priceBtc': '0.000043111074987',
#   'percentChange24hUsd': '-3.589984637571074731',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'eCash',
#   'symbol': 'XEC',
#   'priceUsd': '0.00010989',
#   'priceBtc': '2.3412286e-9',
#   'percentChange24hUsd': '-2.667661630088342234',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Raydium',
#   'symbol': 'RAY',
#   'priceUsd': '7.3875',
#   'priceBtc': '0.0001573921751748',
#   'percentChange24hUsd': '-5.050329821116066541',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Alpaca Finance',
#   'symbol': 'ALPACA',
#   'priceUsd': '0.50985',
#   'priceBtc': '0.0000108624569222',
#   'percentChange24hUsd': '0.14472019199399239',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'MOBOX',
#   'symbol': 'MBOX',
#   'priceUsd': '5.1195',
#   'priceBtc': '0.0001090719784511',
#   'percentChange24hUsd': '-4.533471078396270237',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Voyager Token',
#   'symbol': 'VGX',
#   'priceUsd': '3.158',
#   'priceBtc': '0.0000672818259495',
#   'percentChange24hUsd': '-7.869655663242765141',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'WAXP',
#   'symbol': 'WAXP',
#   'priceUsd': '0.46825',
#   'priceBtc': '0.0000099761605449',
#   'percentChange24hUsd': '-0.428697267605700406',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tribe',
#   'symbol': 'TRIBE',
#   'priceUsd': '0.9609',
#   'priceBtc': '0.0000204721680034',
#   'percentChange24hUsd': '-1.089039503967224461',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Gnosis',
#   'symbol': 'GNO',
#   'priceUsd': '441.9',
#   'priceBtc': '0.0094147684886272',
#   'percentChange24hUsd': '-1.727388782918352464',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Gala',
#   'symbol': 'GALA',
#   'priceUsd': '0.470195',
#   'priceBtc': '0.0000100175991616',
#   'percentChange24hUsd': '-5.195770705582045332',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Illuvium',
#   'symbol': 'ILV',
#   'priceUsd': '1116.85',
#   'priceBtc': '0.0237947141582334',
#   'percentChange24hUsd': '-5.914947059762053034',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Yield Guild Games',
#   'symbol': 'YGG',
#   'priceUsd': '5.1555',
#   'priceBtc': '0.0001098389657007',
#   'percentChange24hUsd': '-6.46094797706343722',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': '1INCHUP',
#   'symbol': '1INCHUP',
#   'priceUsd': '0.065369',
#   'priceBtc': '0.0000013926997088',
#   'percentChange24hUsd': '0.00722621365782962',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': '1INCHDOWN',
#   'symbol': '1INCHDOWN',
#   'priceUsd': '0.006117',
#   'priceBtc': '1.303239168e-7',
#   'percentChange24hUsd': '0.00722621131140288',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'dYdX',
#   'symbol': 'DYDX',
#   'priceUsd': '7.9755',
#   'priceBtc': '0.0001699196335846',
#   'percentChange24hUsd': '-6.565028679634171081',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Bonfida',
#   'symbol': 'FIDA',
#   'priceUsd': '5.1715',
#   'priceBtc': '0.0001101798489227',
#   'percentChange24hUsd': '-5.63996161835281845',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Adventure Gold',
#   'symbol': 'AGLD',
#   'priceUsd': '1.5955',
#   'priceBtc': '0.0000339924487975',
#   'percentChange24hUsd': '3.30950432223745457',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Radicle',
#   'symbol': 'RAD',
#   'priceUsd': '9.4665',
#   'priceBtc': '0.0002016856888382',
#   'percentChange24hUsd': '-3.910844256537073448',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Beta Finance',
#   'symbol': 'BETA',
#   'priceUsd': '0.636405',
#   'priceBtc': '0.0000135587366825',
#   'percentChange24hUsd': '-1.453004561137303049',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'SSV Network',
#   'symbol': 'SSV',
#   'priceUsd': '8.7795462097499',
#   'priceBtc': '0.00018705',
#   'percentChange24hUsd': '6.12785152657092209',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Lazio Fan Token',
#   'symbol': 'LAZIO',
#   'priceUsd': '5.12',
#   'priceBtc': '0.0001090826310518',
#   'percentChange24hUsd': '-3.019622292551710454',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Tranchess',
#   'symbol': 'CHESS',
#   'priceUsd': '1.8415',
#   'priceBtc': '0.0000392335283363',
#   'percentChange24hUsd': '0.96672536990801377',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BinaryX',
#   'symbol': 'BNX',
#   'priceUsd': '75.85',
#   'priceBtc': '0.0016159995244679',
#   'percentChange24hUsd': '-14.19063225799896296',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Rari Governance Token',
#   'symbol': 'RGT',
#   'priceUsd': '20.87',
#   'priceBtc': '0.0004446395527442',
#   'percentChange24hUsd': '-6.321776880474302746',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Moonriver',
#   'symbol': 'MOVR',
#   'priceUsd': '187.55',
#   'priceBtc': '0.0039957905183119',
#   'percentChange24hUsd': '-3.143014321785476167',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Manchester City Fan Token',
#   'symbol': 'CITY',
#   'priceUsd': '8.995',
#   'priceBtc': '0.0001916402863888',
#   'percentChange24hUsd': '-4.656597795189173967',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'BENQI',
#   'symbol': 'QI',
#   'priceUsd': '0.1589',
#   'priceBtc': '0.0000033853964989',
#   'percentChange24hUsd': '-5.155784866377629231',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Jasmy',
#   'symbol': 'JASMY',
#   'priceUsd': '0.0786',
#   'priceBtc': '0.0000016745888283',
#   'percentChange24hUsd': '-8.544875155562470301',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Amp',
#   'symbol': 'AMP',
#   'priceUsd': '0.04791',
#   'priceBtc': '0.000001020732198',
#   'percentChange24hUsd': '-4.592867223204067042',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Vulcan Forged PYR',
#   'symbol': 'PYR',
#   'priceUsd': '20.715',
#   'priceBtc': '0.0004413372465307',
#   'percentChange24hUsd': '-10.569838504656919159',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Render Token',
#   'symbol': 'RNDR',
#   'priceUsd': '4.1415',
#   'priceBtc': '0.0000882354915041',
#   'percentChange24hUsd': '-1.067735012872110557',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Alchemix',
#   'symbol': 'ALCX',
#   'priceUsd': '198.1',
#   'priceBtc': '0.0042205603928424',
#   'percentChange24hUsd': '-4.269478071261652304',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Anyswap',
#   'symbol': 'ANY',
#   'priceUsd': '20.175',
#   'priceBtc': '0.000429832437787',
#   'percentChange24hUsd': '-7.234676373154869287',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Zel',
#   'symbol': 'FLUX',
#   'priceUsd': '1.6555',
#   'priceBtc': '0.0000352707608801',
#   'percentChange24hUsd': '-6.250304077727096743',
#   'lastUpdated': '2021-12-17T08:29:10.000Z'},
#  {'name': 'Highstreet',
#   'symbol': 'HIGH',
#   'priceUsd': '25.75',
#   'priceBtc': '0.0005486089354654',
#   'percentChange24hUsd': None,
#   'lastUpdated': '2021-12-17T08:29:10.000Z'}]
